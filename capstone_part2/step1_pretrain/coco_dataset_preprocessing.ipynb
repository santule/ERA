# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2024-01-23 14:16:10--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.170.185, 3.5.19.21, 16.182.71.73, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.170.185|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M   524KB/s    in 4m 54s
#
# 2024-01-23 14:21:04 (840 KB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# !sudo apt-get install unzip

# %%
# !unzip annotations_trainval2017.zip
# Out:
# Archive:  annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
import pickle
import json

# %%
f = open('annotations/captions_train2017.json')
coco_dataset = json.load(f)

# %%
len(coco_dataset['annotations'])
# Out:
# 591753

# %%
# flatten the coco dataset
coco_data_list = []
r = 0
for a_idx, a in enumerate(coco_dataset['annotations']):
    image_id = a['image_id']
    caption  = a['caption']
    for i in coco_dataset['images']:
        if i['id'] == image_id:
            image_url = i['coco_url']
            file_name = i['file_name']
    if a_idx % 10000 == 0:
        print(f"{10000 * r} processed")
        r += 1
  
    coco_data_list.append([image_id,file_name,image_url,caption])
# Out:
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed
# more 3000 processed

# %%
# save as pickle file
with open("coco_dataset_pickle", "wb") as fp:   #Pickling
    pickle.dump(coco_data_list, fp)
